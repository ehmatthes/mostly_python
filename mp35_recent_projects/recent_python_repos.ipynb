# %% [markdown]
# **Query:** What are the most popular Python repositories that have been created in the last year?

# %%
import requests

# Define headers.
headers = {
    "Accept": "application/vnd.github+json",
    "X-GitHub-Api-Version" : "2022-11-28",
    }

# %%
def run_query(url):
    """Run a query, and return list of repo dicts."""
    print(f"Query URL: {url}")
    r = requests.get(url, headers=headers)
    print(f"Status code: {r.status_code}")

    # Convert the response object to a dictionary.
    response_dict = r.json()

    # Show basic information about the query results.
    print(f"Total repositories: {response_dict['total_count']}")
    
    complete_results = not response_dict['incomplete_results']
    print(f"Complete results: {complete_results}")
    
    # Pull the dictionaries for each repository returned.
    repo_dicts = response_dict['items']
    print(f"Repositories returned: {len(repo_dicts)}")
    
    return repo_dicts

# %%
def summarize_repos(repos):
    """Summarize a set of repositories."""
    for repo in repos:
        name = repo['name']
        stars = repo['stargazers_count']
        owner = repo['owner']['login']
        description = repo['description']
        link = repo['html_url']
        
        print(f"\nRepository: {name} ({stars})")
        print(f"  Owner: {owner}")
        print(f"  Description: {description}")
        print(f"  Repository: {link}")

# %% [markdown]
# Filter even more AI-related posts.

# %%
def prune_repos(repos):
    """Return only non AI-related repos."""
    ai_terms = [
        'gpt', 'llama', 'chat', 'llm', 'diffusion', 'alpaca',
        ' ai', 'ai ', 'ai-', '-ai', 'openai', 'whisper',
        'rlhf', 'language model', 'langchain', 'transformer', 'gpu',
        'copilot', 'deep', 'embedding', 'model', 'pytorch',
        'generative', 'opencv',
    ]
    
    non_ai_repos = []
    for repo in repos:
        # Check for ai terms in name, owner, and description.
        name = repo['name'].lower()
        if any(ai_term in name for ai_term in ai_terms):
            continue
            
        owner = repo['owner']['login'].lower()
        if any(ai_term in owner for ai_term in ai_terms):
            continue
        
        #  Prune repos that don't have a description.
        if not repo['description']:
            continue

        description = repo['description'].lower()
        if any(ai_term in description for ai_term in ai_terms):
            continue
        
        non_ai_repos.append(repo)
    
    print(f"Keeping {len(non_ai_repos)} of {len(repos)} repos.")
    return non_ai_repos

# %% [markdown]
# Write a function that can be called with a date range, and a star range.

# %%
def get_repos(start_date, end_date, star_range):
    """Get repos matching given conditions."""
    url = "https://api.github.com/search/repositories"
    url += f"?q=language:python+stars:{star_range}"
    url += "+NOT+gpt+NOT+llama+NOT+chat+NOT+llm+NOT+diffusion"
    url += f"+created:{start_date}..{end_date}"
    url += "&sort=stars&order=desc"
    url += "&per_page=100&page=1"

    repo_dicts = run_query(url)
    pruned_repos = prune_repos(repo_dicts)
    summarize_repos(pruned_repos)

# %%
get_repos('2023-05-15', '2023-06-15', '3..25')
# Out:
# Query URL: https://api.github.com/search/repositories?q=language:python+stars:3..25+NOT+gpt+NOT+llama+NOT+chat+NOT+llm+NOT+diffusion+created:2023-05-15..2023-06-15&sort=stars&order=desc&per_page=100&page=1
# Status code: 200
# Total repositories: 2579
# Complete results: True
# Repositories returned: 100
# Keeping 51 of 100 repos.
#
# Repository: codigo_facilito_downloader (25)
#   Owner: ivansaul
#   Description: Descarga automatizada de Codigo Facilito
#   Repository: https://github.com/ivansaul/codigo_facilito_downloader
#
# Repository: DSMN_dcase2023 (25)
#   Owner: Wangkkklll
#   Description: This is a project that participated in Task 1 of DCASE2023
#   Repository: https://github.com/Wangkkklll/DSMN_dcase2023
#
# Repository: mind-lake-sdk-python (25)
#   Owner: mind-network
#   Description: Mind Lake SDK in Python
#   Repository: https://github.com/mind-network/mind-lake-sdk-python
#
# Repository: github-oidc-checker (25)
#   Owner: Rezonate-io
#   Description: Tools that checks for misconfigured access to Github OIDC from AWS roles and GCP service accounts
#   Repository: https://github.com/Rezonate-io/github-oidc-checker
#
# Repository: CyberRedTeam (24)
#   Owner: CyberRedTeam
#   Description: 公众号的上使用到的工具
#   Repository: https://github.com/CyberRedTeam/CyberRedTeam
#
# Repository: hikvision-poc (24)
#   Owner: sccmdaveli
#   Description: 海康威视iVMS 综合安防任意文件上传 漏洞检测poc
#   Repository: https://github.com/sccmdaveli/hikvision-poc
#
# Repository: BYUCTF-2023 (24)
#   Owner: BYU-CSA
#   Description: Challenges, source code, and writeups for BYUCTF 2023
#   Repository: https://github.com/BYU-CSA/BYUCTF-2023
#
# Repository: C2C_SSH (24)
#   Owner: certifiedtruecopy
#   Description: A program for creating and managing SSH tunnel users
#   Repository: https://github.com/certifiedtruecopy/C2C_SSH
#
# Repository: mobile-face (24)
#   Owner: jankozik
#   Description: A face recognition solution on mobile device.
#   Repository: https://github.com/jankozik/mobile-face
#
# Repository: QPGesture (24)
#   Owner: YoungSeng
#   Description: QPGesture: Quantization-Based and Phase-Guided Motion Matching for Natural Speech-Driven Gesture Generation (CVPR 2023 Highlight)
#   Repository: https://github.com/YoungSeng/QPGesture
#
# Repository: repobench (24)
#   Owner: Leolty
#   Description: Dataset and code for the paper: "RepoBench: Benchmarking Repository-Level Code Auto-Completion Systems"
#   Repository: https://github.com/Leolty/repobench
#
# Repository: taoli (23)
#   Owner: blcuicall
#   Description: "桃李“: 国际中文教育大模型
#   Repository: https://github.com/blcuicall/taoli
#
# Repository: PyProto (23)
#   Owner: Ccccccccvvm
#   Description: protobuf pb-free file for group packet unpacking
#   Repository: https://github.com/Ccccccccvvm/PyProto
#
# Repository: WinClip (23)
#   Owner: caoyunkang
#   Description: [CVPR 2023] Unofficial re-implementation of "WinCLIP: Zero-/Few-Shot Anomaly Classification and Segmentation".
#   Repository: https://github.com/caoyunkang/WinClip
#
# Repository: kandinsky-for-automatic1111 (23)
#   Owner: MMqd
#   Description: Automatic1111 extension adding support for Kandinsky 2.1
#   Repository: https://github.com/MMqd/kandinsky-for-automatic1111
#
# Repository: LayerZeroStats (22)
#   Owner: Failton
#   Description: A simple script for downloading the LayerZero table from Dune and filtering by the specified wallets
#   Repository: https://github.com/Failton/LayerZeroStats
#
# Repository: scenery_spider_web (22)
#   Owner: ChenZixinn
#   Description: Scrapy爬取去哪儿网，并使用Django框架+PyEcharts实现可视化大屏。
#   Repository: https://github.com/ChenZixinn/scenery_spider_web
#
# Repository: text2video (22)
#   Owner: bravekingzhang
#   Description: 半个神器👉一键文本转视频的工具
#   Repository: https://github.com/bravekingzhang/text2video
#
# Repository: Nuclei-Templates (22)
#   Owner: bhataasim1
#   Description: Downlaod all the nuclei Templates created from many Bug Hunters
#   Repository: https://github.com/bhataasim1/Nuclei-Templates
#
# Repository: PMC-VQA (22)
#   Owner: xiaoman-zhang
#   Description: PMC-VQA is a large-scale medical visual question-answering dataset, which contains 227k VQA pairs of 149k images that cover various modalities or diseases.
#   Repository: https://github.com/xiaoman-zhang/PMC-VQA
#
# Repository: MultiPerson (22)
#   Owner: JunukCha
#   Description: Multi-Person 3D Pose and Shape Estimation via Inverse Kinematics and Refinement
#   Repository: https://github.com/JunukCha/MultiPerson
#
# Repository: MLOps_wsPycon2023 (21)
#   Owner: darkanita
#   Description: MLOps Workshop using Weights and Bias (Wandb) and Github Actions.
#   Repository: https://github.com/darkanita/MLOps_wsPycon2023
#
# Repository: tiktok-viewbot (21)
#   Owner: louissiu198
#   Description: Tiktok viewbot botting 400-600 views per seconds, created in pure python
#   Repository: https://github.com/louissiu198/tiktok-viewbot
#
# Repository: PSTrojanFile (21)
#   Owner: hyp3rlinx
#   Description: Unfixed Windows PowerShell Filename Code Execution POC
#   Repository: https://github.com/hyp3rlinx/PSTrojanFile
#
# Repository: handwriting-synthesis (21)
#   Owner: otuva
#   Description: Handwriting Synthesis with RNNs ✏️ (Migrated to TensorFlow v2)
#   Repository: https://github.com/otuva/handwriting-synthesis
#
# Repository: RL-ViGen (21)
#   Owner: gemcollector
#   Description: This is the repo for RL-ViGen
#   Repository: https://github.com/gemcollector/RL-ViGen
#
# Repository: audiocraft-webui (21)
#   Owner: CoffeeVampir3
#   Description: Quick webui for audiocraft
#   Repository: https://github.com/CoffeeVampir3/audiocraft-webui
#
# Repository: bnn-bo (21)
#   Owner: yucenli
#   Description: Bayesian Neural Network Surrogates for Bayesian Optimization
#   Repository: https://github.com/yucenli/bnn-bo
#
# Repository: RouteDisplay (21)
#   Owner: lintheyoung
#   Description: Display the robot's 2D route in realtime
#   Repository: https://github.com/lintheyoung/RouteDisplay
#
# Repository: easymms (21)
#   Owner: abdeladim-s
#   Description: A simple Python package to easily use Meta's Massively Multilingual Speech (MMS) project
#   Repository: https://github.com/abdeladim-s/easymms
#
# Repository: EasyTemporalPointProcess (21)
#   Owner: ant-research
#   Description: EasyTPP: Towards Open Benchmarking the Neural Temporal Point Processes
#   Repository: https://github.com/ant-research/EasyTemporalPointProcess
#
# Repository: ACE_phonemes (20)
#   Owner: timedomain-tech
#   Description: a guide to grapheme-to-phoneme conversion and phoneme list for ace singing voice synthesis engine
#   Repository: https://github.com/timedomain-tech/ACE_phonemes
#
# Repository: cookiecutter-serverless-python (20)
#   Owner: ran-isenberg
#   Description: Cookiecutter template for new Serverless services - CDK deployment code, pipeline and handler are covered with best practices built in.
#   Repository: https://github.com/ran-isenberg/cookiecutter-serverless-python
#
# Repository: pdf2md (20)
#   Owner: eiaserinnys
#   Description: This project, pdf2md, transforms academic paper PDF files into digestible text files. By analyzing the layout of the PDF file, the application restructures paragraphs and translates desired content. The final result is a conveniently exported text file.
#   Repository: https://github.com/eiaserinnys/pdf2md
#
# Repository: bloom_tuning (20)
#   Owner: zejunwang1
#   Description: BLOOM 模型的指令微调
#   Repository: https://github.com/zejunwang1/bloom_tuning
#
# Repository: NeRFLiX_CPVR2023 (20)
#   Owner: redrock303
#   Description: official NeRFLiX implementation
#   Repository: https://github.com/redrock303/NeRFLiX_CPVR2023
#
# Repository: CorrMatch (20)
#   Owner: BBBBchan
#   Description: Official code for "CorrMatch: Label Propagation via Correlation Matching for Semi-Supervised Semantic Segmentation"
#   Repository: https://github.com/BBBBchan/CorrMatch
#
# Repository: WeatherWallpaper (20)
#   Owner: BiomeBits
#   Description: Script that uses Lively Wallpaper to change desktop wallpaper to a different video depending on the time of day and weather
#   Repository: https://github.com/BiomeBits/WeatherWallpaper
#
# Repository: bybit-smm (19)
#   Owner: beatzxbt
#   Description: bybit simple market maker
#   Repository: https://github.com/beatzxbt/bybit-smm
#
# Repository: 10inch-player (19)
#   Owner: tltangliang
#   Description: A 20inch HiFi music player with 7.84 touchscreen
#   Repository: https://github.com/tltangliang/10inch-player
#
# Repository: LIV (19)
#   Owner: penn-pal-lab
#   Description: Official repository for "LIV: Language-Image Representations and Rewards for Robotic Control" (ICML 2023)
#   Repository: https://github.com/penn-pal-lab/LIV
#
# Repository: UNSB (19)
#   Owner: cyclomon
#   Description: Official Repository of "Unpaired Image-to-Image Translation via Neural Schrödinger Bridge"
#   Repository: https://github.com/cyclomon/UNSB
#
# Repository: AlignScore (19)
#   Owner: yuh-zha
#   Description: AlignScore, a metric for factual consistency evaluation.
#   Repository: https://github.com/yuh-zha/AlignScore
#
# Repository: uvk5-reverse-engineering (19)
#   Owner: sq5bpf
#   Description: Efforts to reverse engineer the Quanscheng UV-K5 radio
#   Repository: https://github.com/sq5bpf/uvk5-reverse-engineering
#
# Repository: select-images-by-indices (19)
#   Owner: rickwang28574
#   Description: This Python script selects a specific set of images from a folder and copies them to a destination folder. It uses the os and shutil libraries to select images based on specific indices. Users can modify the script to fit their needs. It's useful for batch image selection and copying for data analysis, machine learning, and more.
#   Repository: https://github.com/rickwang28574/select-images-by-indices
#
# Repository: MalSys (19)
#   Owner: UncleJ4ck
#   Description: Malsys is a project designed to validate and analyze files for potential malware signatures.
#   Repository: https://github.com/UncleJ4ck/MalSys
#
# Repository: Richard-roop (18)
#   Owner: RichardErkhov
#   Description: for those who wants some speed
#   Repository: https://github.com/RichardErkhov/Richard-roop
#
# Repository: CVE-2023-28771-PoC (18)
#   Owner: BenHays142
#   Description: PoC for CVE-2023-28771 based on Rapid7's excellent writeup
#   Repository: https://github.com/BenHays142/CVE-2023-28771-PoC
#
# Repository: python-eda (18)
#   Owner: PatrickKalkman
#   Description: A repository that contains all the examples that go with a Medium article called Mastering Event-Driven Architecture in Python
#   Repository: https://github.com/PatrickKalkman/python-eda
#
# Repository: Python-course-exercises-Jadi-1 (18)
#   Owner: FarnamJavadi
#   Description: Exercises of Jadi's introductory Python course
#   Repository: https://github.com/FarnamJavadi/Python-course-exercises-Jadi-1
#
# Repository: dm-login (18)
#   Owner: ClassmateLin
#   Description: 大麦登录
#   Repository: https://github.com/ClassmateLin/dm-login

# %%
get_repos('2023-05-15', '2023-06-15', '0')
# Out:
# Query URL: https://api.github.com/search/repositories?q=language:python+stars:0+NOT+gpt+NOT+llama+NOT+chat+NOT+llm+NOT+diffusion+created:2023-05-15..2023-06-15&sort=stars&order=desc&per_page=100&page=1
# Status code: 200
# Total repositories: 296039
# Complete results: True
# Repositories returned: 100
# Keeping 19 of 100 repos.
#
# Repository: bsv-chef (0)
#   Owner: JulianFrattini
#   Description: A simple toy system for the course PA1417 Basic System Verification
#   Repository: https://github.com/JulianFrattini/bsv-chef
#
# Repository: qa (0)
#   Owner: ipetersenpai
#   Description: QA
#   Repository: https://github.com/ipetersenpai/qa
#
# Repository: AWS-prac (0)
#   Owner: LIKELION-KMU-11TH
#   Description: AWS EC2 배포 연습
#   Repository: https://github.com/LIKELION-KMU-11TH/AWS-prac
#
# Repository: coding-challenge (0)
#   Owner: maxiyommi
#   Description: Desafío de Python para poner en práctica lo aprendido.
#   Repository: https://github.com/maxiyommi/coding-challenge
#
# Repository: guessmynumber (0)
#   Owner: iavila24
#   Description: Collaborative Game Class 372 - Introduction to Python (2023-1)
#   Repository: https://github.com/iavila24/guessmynumber
#
# Repository: gitworkflow3 (0)
#   Owner: iavila24
#   Description: Workflow 3 for class 372 python collaborative
#   Repository: https://github.com/iavila24/gitworkflow3
#
# Repository: 2023SE (0)
#   Owner: cjparkara
#   Description: 2023 Software Engineering Subject
#   Repository: https://github.com/cjparkara/2023SE
#
# Repository: padawans122week1day1 (0)
#   Owner: smtsuchi
#   Description: Git Hub Demo
#   Repository: https://github.com/smtsuchi/padawans122week1day1
#
# Repository: tekwillLiveV3 (0)
#   Owner: mtricolici98
#   Description: Live Materials
#   Repository: https://github.com/mtricolici98/tekwillLiveV3
#
# Repository: cocherito_lere (0)
#   Owner: elMestreAcademy
#   Description: Ejercicio de clases y Objetos
#   Repository: https://github.com/elMestreAcademy/cocherito_lere
#
# Repository: pytests (0)
#   Owner: morozovkm
#   Description: Для тестов
#   Repository: https://github.com/morozovkm/pytests
#
# Repository: quotes (0)
#   Owner: SharafatKarim
#   Description: A open collection of Quotes. Feel free to contribute!
#   Repository: https://github.com/SharafatKarim/quotes
#
# Repository: log680 (0)
#   Owner: MarioGith
#   Description: LOG-680 : Oxygen CS Template
#   Repository: https://github.com/MarioGith/log680
#
# Repository: StreamlitCheckApp (0)
#   Owner: sherry0429
#   Description: Streamlit Checkout Application
#   Repository: https://github.com/sherry0429/StreamlitCheckApp
#
# Repository: test-1 (0)
#   Owner: Kogoon
#   Description: test
#   Repository: https://github.com/Kogoon/test-1
#
# Repository: gwolnadri_project (0)
#   Owner: taeseokyoung
#   Description: 23.06.05. 궐나드리 : 궁궐 관람 예약 및 큐레이션, 한복 대여 서비스까지!
#   Repository: https://github.com/taeseokyoung/gwolnadri_project
#
# Repository: ProjExD_05 (0)
#   Owner: c0a220106d
#   Description: プロジェクト演習D（５回目）
#   Repository: https://github.com/c0a220106d/ProjExD_05
#
# Repository: b4_exhibitions_backend (0)
#   Owner: sdoram
#   Description: B4조 지금은 전시상황 백엔드
#   Repository: https://github.com/sdoram/b4_exhibitions_backend
#
# Repository: Traffooze (0)
#   Owner: NamLeeGG
#   Description: FYP-23-S2-23 -  Traffooze
#   Repository: https://github.com/NamLeeGG/Traffooze

# %%
get_repos('2023-05-15', '2023-06-15', '3..10')
# Out:
# Query URL: https://api.github.com/search/repositories?q=language:python+stars:3..10+NOT+gpt+NOT+llama+NOT+chat+NOT+llm+NOT+diffusion+created:2023-05-15..2023-06-15&sort=stars&order=desc&per_page=100&page=1
# Status code: 200
# Total repositories: 2225
# Complete results: True
# Repositories returned: 100
# Keeping 54 of 100 repos.
#
# Repository: AutoPicX (10)
#   Owner: git-itsjoel
#   Description: Telegram User Bot To Change Profile Pic/Picture Automatically After A Specified Time
#   Repository: https://github.com/git-itsjoel/AutoPicX
#
# Repository: squlearn (10)
#   Owner: sQUlearn
#   Description: sklearn interface for quantum algorithms
#   Repository: https://github.com/sQUlearn/squlearn
#
# Repository: fno-pre-req (10)
#   Owner: xcode88
#   Description: Basic set of key information to kick off the trading session.
#   Repository: https://github.com/xcode88/fno-pre-req
#
# Repository: char-detection (10)
#   Owner: fanqie03
#   Description: 🔥Char detection base on crnn 字符（单字）检测基于CRNN
#   Repository: https://github.com/fanqie03/char-detection
#
# Repository: aws-health-events-insight (10)
#   Owner: aws-samples
#   Description: centralized approach to store and analyze AWS Health events(PHD and SHD)
#   Repository: https://github.com/aws-samples/aws-health-events-insight
#
# Repository: NexToU (10)
#   Owner: PengchengShi1220
#   Description: NexToU: Efficient Topology-Aware U-Net for Medical Image Segmentation
#   Repository: https://github.com/PengchengShi1220/NexToU
#
# Repository: AbletonAutoColor (10)
#   Owner: CoryWBoris
#   Description: Automatic Color Assignment Based On Name In Ableton Live
#   Repository: https://github.com/CoryWBoris/AbletonAutoColor
#
# Repository: bluesky-feed-generator (10)
#   Owner: MarshalX
#   Description: Bsky custom feed algorithms server in Python!
#   Repository: https://github.com/MarshalX/bluesky-feed-generator
#
# Repository: omr (10)
#   Owner: duhanguler
#   Description: Optical Mark Recognition Project
#   Repository: https://github.com/duhanguler/omr
#
# Repository: gmsad (10)
#   Owner: cea-sec
#   Description: gmsad manages Active Directory group Managed Service Account (gMSA) on Linux
#   Repository: https://github.com/cea-sec/gmsad
#
# Repository: Sakura_embyboss (10)
#   Owner: berry8838
#   Description: 一个个人风格明显的垃圾bot，用于管理emby用户
#   Repository: https://github.com/berry8838/Sakura_embyboss
#
# Repository: cicfighters-py3 (10)
#   Owner: thlmenezes
#   Description: Atualização do jogo CiCfighters https://github.com/DaniloT/cicfighters para python 3 e pygame 2.4.0
#   Repository: https://github.com/thlmenezes/cicfighters-py3
#
# Repository: bquest (10)
#   Owner: ottogroup
#   Description: Effortlessly validate and test your Google BigQuery queries with the power of pandas DataFrames in Python.
#   Repository: https://github.com/ottogroup/bquest
#
# Repository: uniood (10)
#   Owner: szubing
#   Description: A code framework for implementing UniDA
#   Repository: https://github.com/szubing/uniood
#
# Repository: exprscript (10)
#   Owner: sdingcn
#   Description: (Interpreter) a dynamically typed functional programming language with first class continuations | (解释器) 一个动态类型函数式语言, 支持一等续延
#   Repository: https://github.com/sdingcn/exprscript
#
# Repository: SwiftSnipe (10)
#   Owner: Sxvxgee
#   Description: The ultimate Discord Name Sniper with lightning-fast speed, intuitive interface, webhook support, enhanced accuracy, customization options, and top-notch security.
#   Repository: https://github.com/Sxvxgee/SwiftSnipe
#
# Repository: HardSATGEN (10)
#   Owner: Thinklab-SJTU
#   Description: Official implementation of SIGKDD 2023 paper "HardSATGEN: Understanding the Difficulty of Hard SAT Formula Generation and A Strong Structure-Hardness-Aware Baseline".
#   Repository: https://github.com/Thinklab-SJTU/HardSATGEN
#
# Repository: boosttravel-django (10)
#   Owner: ogokdas
#   Description: Boosttravel - Django Tourist Guide application provides online tourist guide services to users.
#   Repository: https://github.com/ogokdas/boosttravel-django
#
# Repository: hazardous (10)
#   Owner: soda-inria
#   Description: Competing Risks and Survival Analysis
#   Repository: https://github.com/soda-inria/hazardous
#
# Repository: Pulo (10)
#   Owner: baimao-box
#   Description: An automated penetration testing information collection tool / 一款自动化渗透测试信息搜集类工具
#   Repository: https://github.com/baimao-box/Pulo
#
# Repository: Assessor360 (10)
#   Owner: TianheWu
#   Description: Assessor360: Multi-sequence Network for Blind Omnidirectional Image Quality Assessment
#   Repository: https://github.com/TianheWu/Assessor360
#
# Repository: Funcaptcha-Solver (10)
#   Owner: Pr0t0ns
#   Description: Funcaptcha Audio Solver made by pr0t0n
#   Repository: https://github.com/Pr0t0ns/Funcaptcha-Solver
#
# Repository: codezen (10)
#   Owner: mmaorc
#   Description: Your indispensable partner in programming
#   Repository: https://github.com/mmaorc/codezen
#
# Repository: rewe-to-grocy (10)
#   Owner: fzakfeld
#   Description: Import digital REWE receipts into Grocy!
#   Repository: https://github.com/fzakfeld/rewe-to-grocy
#
# Repository: seaborn_polars (10)
#   Owner: pavelcherepan
#   Description: Wrapper allowing to use Polars DataFrames and LazyFrames for plotting with seaborn
#   Repository: https://github.com/pavelcherepan/seaborn_polars
#
# Repository: CTkThemeMaker (10)
#   Owner: Akascape
#   Description: A quick and easy-to-use theme builder for customtkinter!
#   Repository: https://github.com/Akascape/CTkThemeMaker
#
# Repository: django-ninja-crud (10)
#   Owner: hbakri
#   Description: 🏄‍♂️ Fast Django CRUD APIs with Django Ninja.
#   Repository: https://github.com/hbakri/django-ninja-crud
#
# Repository: RbA (10)
#   Owner: NazirNayal8
#   Description: Official code for RbA: Segmenting Unknown Regions Rejected by All
#   Repository: https://github.com/NazirNayal8/RbA
#
# Repository: datasieve (10)
#   Owner: emergentmethods
#   Description: Adding coherence to the SKLearn pipeline
#   Repository: https://github.com/emergentmethods/datasieve
#
# Repository: youtube-video-summarizer (10)
#   Owner: ibnaleem
#   Description: Summarize any YouTube video into ten concise bullet points along with a summary. Extract the key information and main ideas from a video, saving you time and effort.
#   Repository: https://github.com/ibnaleem/youtube-video-summarizer
#
# Repository: leetcode-screenshotter (10)
#   Owner: akhilkammila
#   Description: screenshots leetcode editorials and problems
#   Repository: https://github.com/akhilkammila/leetcode-screenshotter
#
# Repository: netdoc (10)
#   Owner: dainok
#   Description: Automatic Network Documentation plugin for NetBox
#   Repository: https://github.com/dainok/netdoc
#
# Repository: ALIA (10)
#   Owner: lisadunlap
#   Description: Augmenting with Language-guided Image Augmentation
#   Repository: https://github.com/lisadunlap/ALIA
#
# Repository: GetNews (10)
#   Owner: vluz
#   Description: Dirty simple python script for news checking
#   Repository: https://github.com/vluz/GetNews
#
# Repository: ecg-qa (10)
#   Owner: Jwoo5
#   Description: Repository for distributing ECG-QA dataset
#   Repository: https://github.com/Jwoo5/ecg-qa
#
# Repository: G-Aligner (10)
#   Owner: CSi-Studio
#   Description: G-Aligner: a graph-based feature alignment method for untargeted LC-MS-based metabolomics
#   Repository: https://github.com/CSi-Studio/G-Aligner
#
# Repository: tpms (10)
#   Owner: MarkoYaminsky
#   Description: This is repository to store code for tpms (theory of probability and mathematical statistics) labs
#   Repository: https://github.com/MarkoYaminsky/tpms
#
# Repository: BERT-Event-Extraction (10)
#   Owner: taishan1994
#   Description: 使用bert进行事件抽取。
#   Repository: https://github.com/taishan1994/BERT-Event-Extraction
#
# Repository: CL-Detection2023 (10)
#   Owner: szuboy
#   Description: CL-Detection2023 Challenge Official Repository
#   Repository: https://github.com/szuboy/CL-Detection2023
#
# Repository: Final-Project-BSIS-1 (9)
#   Owner: jhonbonjuvi
#   Description: Compiled Projects Individual
#   Repository: https://github.com/jhonbonjuvi/Final-Project-BSIS-1
#
# Repository: teleprompter (9)
#   Owner: Nokse22
#   Description: A simple Gtk4 application to read scrolling text from your screen
#   Repository: https://github.com/Nokse22/teleprompter
#
# Repository: bungee-refuel (9)
#   Owner: v1aas
#   Description: Рефуел из polygon/avax в сети bsc,fantom, avax/polygon посредством моста https://bungee.exchange/
#   Repository: https://github.com/v1aas/bungee-refuel
#
# Repository: py-bungee-refueler (9)
#   Owner: whonion
#   Description: Batch send gas-token with bungee.exchange
#   Repository: https://github.com/whonion/py-bungee-refueler
#
# Repository: zkLightClient-MintBridgeClaim (9)
#   Owner: web3moves
#   Description: Mint, bridge and claim for zkLightClient NFT at https://zkbridge.com/zknft
#   Repository: https://github.com/web3moves/zkLightClient-MintBridgeClaim
#
# Repository: GSMissionControl (9)
#   Owner: GareebScientist
#   Description: A collection of tools to ease and enhance Gareeb Scientists Livetstreams
#   Repository: https://github.com/GareebScientist/GSMissionControl
#
# Repository: CommitDraw (9)
#   Owner: Tankolom-X
#   Description: Allows you to convert your image into the activity on your GitHub heatmap, as well as fill it randomly
#   Repository: https://github.com/Tankolom-X/CommitDraw
#
# Repository: cgsubmit (9)
#   Owner: FrequentlyMissedDeadlines
#   Description: a tool to analyze the results of your submits in codingame competitions
#   Repository: https://github.com/FrequentlyMissedDeadlines/cgsubmit
#
# Repository: Egy-Crack (9)
#   Owner: dragonked2
#   Description: #Egy-Crack-Ethereum PrivateKey (Generator-Cracker)
#   Repository: https://github.com/dragonked2/Egy-Crack
#
# Repository: The-Distiller (9)
#   Owner: Agora-X
#   Description: Generate High Quality textual or multi-modal datasets with Agents
#   Repository: https://github.com/Agora-X/The-Distiller
#
# Repository: jax-so-vits-svc-5.0 (9)
#   Owner: flyingblackshark
#   Description: Rewrite so-vits-svc-5.0 in jax
#   Repository: https://github.com/flyingblackshark/jax-so-vits-svc-5.0
#
# Repository: Diablo-4-XP-and-gold-per-hour (9)
#   Owner: akjroller
#   Description: A program that watches Diablo 4 and can tell you how much gold and xp you gain per hour
#   Repository: https://github.com/akjroller/Diablo-4-XP-and-gold-per-hour
#
# Repository: baembal (9)
#   Owner: youknowone
#   Description: Boost ast.parse with RustPython-powered parser technology
#   Repository: https://github.com/youknowone/baembal
#
# Repository: Novis (9)
#   Owner: r3nko
#   Description: Discord token logger.
#   Repository: https://github.com/r3nko/Novis
#
# Repository: Fast13uy (9)
#   Owner: kee1ongz
#   Description: Taobao Auto Purchase Tool/ 简单的淘宝自动秒杀
#   Repository: https://github.com/kee1ongz/Fast13uy

# %%
get_repos('2023-06-10', '2023-06-15', '3..10')
# Out:
# Query URL: https://api.github.com/search/repositories?q=language:python+stars:3..10+NOT+gpt+NOT+llama+NOT+chat+NOT+llm+NOT+diffusion+created:2023-06-10..2023-06-15&sort=stars&order=desc&per_page=100&page=1
# Status code: 200
# Total repositories: 301
# Complete results: True
# Repositories returned: 100
# Keeping 49 of 100 repos.
#
# Repository: django-ninja-crud (10)
#   Owner: hbakri
#   Description: 🏄‍♂️ Fast Django CRUD APIs with Django Ninja.
#   Repository: https://github.com/hbakri/django-ninja-crud
#
# Repository: Diablo-4-XP-and-gold-per-hour (9)
#   Owner: akjroller
#   Description: A program that watches Diablo 4 and can tell you how much gold and xp you gain per hour
#   Repository: https://github.com/akjroller/Diablo-4-XP-and-gold-per-hour
#
# Repository: Novis (9)
#   Owner: r3nko
#   Description: Discord token logger.
#   Repository: https://github.com/r3nko/Novis
#
# Repository: imagenet-12k (9)
#   Owner: rwightman
#   Description: ImageNet-12k subset of ImageNet-21k (fall11)
#   Repository: https://github.com/rwightman/imagenet-12k
#
# Repository: Outlook-email (8)
#   Owner: tshdhhdjf
#   Description: Outlook-email
#   Repository: https://github.com/tshdhhdjf/Outlook-email
#
# Repository: graph-blockren (8)
#   Owner: avan-pra
#   Description: Etherum transaction visualizer using neo4j
#   Repository: https://github.com/avan-pra/graph-blockren
#
# Repository: getarch (8)
#   Owner: fabifont
#   Description: A versatile Arch Linux installation helper script and library
#   Repository: https://github.com/fabifont/getarch
#
# Repository: py-factory (8)
#   Owner: chanrt
#   Description: A simplified Factorio clone developed in Python
#   Repository: https://github.com/chanrt/py-factory
#
# Repository: dreamsim (8)
#   Owner: ssundaram21
#   Description: DreamSim: Learning New Dimensions of Human Visual Similarity using Synthetic Data
#   Repository: https://github.com/ssundaram21/dreamsim
#
# Repository: 0click_HTB (7)
#   Owner: brutuspt
#   Description: This repository contains 0 click exploits to some HackTheBox machines, I used it to study for OSWE
#   Repository: https://github.com/brutuspt/0click_HTB
#
# Repository: Machine_Learning (7)
#   Owner: RuiXiangLiuA
#   Description: Self-learning machine learning
#   Repository: https://github.com/RuiXiangLiuA/Machine_Learning
#
# Repository: ehr_SafeCodeEncode_tamper (7)
#   Owner: jdr2021
#   Description: 宏景ehr sql注入的tamper脚本（sqlmap使用）
#   Repository: https://github.com/jdr2021/ehr_SafeCodeEncode_tamper
#
# Repository: Making-WaterMark-ML (7)
#   Owner: rlmathguru
#   Description: This project is generating water mark and detecting project
#   Repository: https://github.com/rlmathguru/Making-WaterMark-ML
#
# Repository: cg-stubs (7)
#   Owner: LumaPictures
#   Description: Python stubs for VFX and Animation
#   Repository: https://github.com/LumaPictures/cg-stubs
#
# Repository: docker-image-layer-explorer (7)
#   Owner: Kartik1397
#   Description: CLI tool to view and extract content of docker image layer
#   Repository: https://github.com/Kartik1397/docker-image-layer-explorer
#
# Repository: FEA-SV (7)
#   Owner: cjs123123
#   Description: Auditable Task Allocation Scheme Based on Functional Encryption in Distributed Spatial Crowdsourcing
#   Repository: https://github.com/cjs123123/FEA-SV
#
# Repository: KETM (7)
#   Owner: 1094701018
#   Description: 基于知识增强的文本匹配模型
#   Repository: https://github.com/1094701018/KETM
#
# Repository: InstructMT (7)
#   Owner: wxjiao
#   Description: A collection of instruction data and scripts for machine translation.
#   Repository: https://github.com/wxjiao/InstructMT
#
# Repository: Over-Paas-Captcha-ML (7)
#   Owner: rlmathguru
#   Description: This project is over passing Captcha project.
#   Repository: https://github.com/rlmathguru/Over-Paas-Captcha-ML
#
# Repository: Detect-clothes-ML-PyQT (7)
#   Owner: rlmathguru
#   Description: This project is detecting Clothes project using ML and PyQT
#   Repository: https://github.com/rlmathguru/Detect-clothes-ML-PyQT
#
# Repository: Code-Chef-String-Operation- (7)
#   Owner: THARUN1526
#   Description: Solution In Python With Problem Explanation And Algorithm
#   Repository: https://github.com/THARUN1526/Code-Chef-String-Operation-
#
# Repository: covid2019-crawer (6)
#   Owner: iris91986
#   Description: covid2019-crawer
#   Repository: https://github.com/iris91986/covid2019-crawer
#
# Repository: huyidemco4 (6)
#   Owner: huyidemco
#   Description: huyidemco4
#   Repository: https://github.com/huyidemco/huyidemco4
#
# Repository: franson4 (6)
#   Owner: huyfranson
#   Description: franson4
#   Repository: https://github.com/huyfranson/franson4
#
# Repository: thuanlong4 (6)
#   Owner: Huythuanlong
#   Description: thuanlong4
#   Repository: https://github.com/Huythuanlong/thuanlong4
#
# Repository: huyidi4 (6)
#   Owner: huyidigroup
#   Description: huyidi4
#   Repository: https://github.com/huyidigroup/huyidi4
#
# Repository: cadcam4 (6)
#   Owner: Huyvucadcam
#   Description: cadcam4
#   Repository: https://github.com/Huyvucadcam/cadcam4
#
# Repository: jameboat2 (6)
#   Owner: huyjameboat
#   Description: jameboat2
#   Repository: https://github.com/huyjameboat/jameboat2
#
# Repository: quanghuy24094 (6)
#   Owner: quanghuy2409
#   Description: quanghuy24094
#   Repository: https://github.com/quanghuy2409/quanghuy24094
#
# Repository: sd-webui-prompt-history (6)
#   Owner: namkazt
#   Description: Automatic store your generation info with image and apply back anytime.
#   Repository: https://github.com/namkazt/sd-webui-prompt-history
#
# Repository: jd_ql_assistant (6)
#   Owner: SSJACK8582
#   Description: 京东青龙抢购助手
#   Repository: https://github.com/SSJACK8582/jd_ql_assistant
#
# Repository: aliproduct-BLIP-cvpr2023 (6)
#   Owner: JiaYanhao
#   Description: Aliproduct competition solution
#   Repository: https://github.com/JiaYanhao/aliproduct-BLIP-cvpr2023
#
# Repository: MedNeXt (6)
#   Owner: MIC-DKFZ
#   Description: MedNeXt is a fully ConvNeXt architecture for 3D medical image segmentation.
#   Repository: https://github.com/MIC-DKFZ/MedNeXt
#
# Repository: PanoHead (6)
#   Owner: SizheAn
#   Description: Code Repository for CVPR 2023 Paper "PanoHead: Geometry-Aware 3D Full-Head Synthesis in 360 degree"
#   Repository: https://github.com/SizheAn/PanoHead
#
# Repository: YSUTools (6)
#   Owner: KamijoToma
#   Description: 针对燕山大学自主研发的小工具合集
#   Repository: https://github.com/KamijoToma/YSUTools
#
# Repository: chouxiang-dict (6)
#   Owner: tobyxdd
#   Description: 新抽象字典 (Telegram 贴纸包)
#   Repository: https://github.com/tobyxdd/chouxiang-dict
#
# Repository: StarRailAutoPilot (6)
#   Owner: Xe-No
#   Description: 小地图寻路的锄大地
#   Repository: https://github.com/Xe-No/StarRailAutoPilot
#
# Repository: juisee (6)
#   Owner: yuru7
#   Description: Juisee は、欧文フォント JuliaMono と日本語フォント LINE Seed JP を合成したプログラミング向けフォントです。
#   Repository: https://github.com/yuru7/juisee
#
# Repository: efrt (5)
#   Owner: thanhmom666999
#   Description: Tinh Hinh Anh Em The Nao Roi - Testnet that la vui zozozo
#   Repository: https://github.com/thanhmom666999/efrt
#
# Repository: calibration-calculation (5)
#   Owner: wollie418
#   Description: calibration calculation
#   Repository: https://github.com/wollie418/calibration-calculation
#
# Repository: SegRap2023 (5)
#   Owner: HiLab-git
#   Description: [SegRap2023]A challenge about organ-at-risk and gross-tumor-volume segmentation in adaptive radiotherapy hosted on MICCAI2023.
#   Repository: https://github.com/HiLab-git/SegRap2023
#
# Repository: pythorhead (5)
#   Owner: db0
#   Description: A python library for interacting with Lemmy
#   Repository: https://github.com/db0/pythorhead
#
# Repository: CVE-2023-20887 (5)
#   Owner: miko550
#   Description: VMWare vRealize Network Insight Pre-Authenticated RCE (CVE-2023-20887)
#   Repository: https://github.com/miko550/CVE-2023-20887
#
# Repository: mongo-to-s3 (5)
#   Owner: IamLizu
#   Description: Automated script generator to backup MongoDB databases to Amazon S3.
#   Repository: https://github.com/IamLizu/mongo-to-s3
#
# Repository: Cloudflare-Scanner (5)
#   Owner: SingleDevX
#   Description: Cloudflare scanner for finding clean IPs
#   Repository: https://github.com/SingleDevX/Cloudflare-Scanner
#
# Repository: anonymous-numbers-market-analytics (5)
#   Owner: qpwedev
#   Description: Telegram bot to share statistical data about anonymous Telegram numbers
#   Repository: https://github.com/qpwedev/anonymous-numbers-market-analytics
#
# Repository: EwaldMP (5)
#   Owner: arthurkosmala
#   Description: Reference implementation of "Ewald-based Long-Range Message Passing for Molecular Graphs" (ICML 2023)
#   Repository: https://github.com/arthurkosmala/EwaldMP
#
# Repository: FunPayVertex (5)
#   Owner: NightStrang6r
#   Description: Бот для упрощения использования площадки FunPay
#   Repository: https://github.com/NightStrang6r/FunPayVertex
#
# Repository: anime-character-chinese-dataset (5)
#   Owner: artist3yehe
#   Description: 二次元角色中文语料库
#   Repository: https://github.com/artist3yehe/anime-character-chinese-dataset

# %% [markdown]
# Most popular projects in the last week?

# %%
get_repos('2023-01-14', '2023-05-31', '3..23')
# Out:
# Query URL: https://api.github.com/search/repositories?q=language:python+stars:3..23+NOT+gpt+NOT+llama+NOT+chat+NOT+llm+NOT+diffusion+created:2023-01-14..2023-05-31&sort=stars&order=desc&per_page=100&page=1
# Status code: 200
# Total repositories: 18570
# Complete results: False
# Repositories returned: 100
# Keeping 66 of 100 repos.
#
# Repository: Fire-Liker (23)
#   Owner: RozhakXD
#   Description: Get Views On Tiktok Without Login!
#   Repository: https://github.com/RozhakXD/Fire-Liker
#
# Repository: django_style_guide (23)
#   Owner: amirbahador-hub
#   Description: a cookiecutter for django_style_guide
#   Repository: https://github.com/amirbahador-hub/django_style_guide
#
# Repository: sakera (23)
#   Owner: FerlyXyn
#   Description: Multi Brute Force Facebook - Crack Facebook With Login - Free For Now
#   Repository: https://github.com/FerlyXyn/sakera
#
# Repository: text_search (23)
#   Owner: k2-fsa
#   Description: Some fast-ish algorithms for batch text search in moderate-sized collections, intended for data cleanup
#   Repository: https://github.com/k2-fsa/text_search
#
# Repository: flight-analysis (23)
#   Owner: celebi-pkg
#   Description: Python package to scrape flight data from Google Flights and analyzes prices. Can determine optimal flight from date, place, and price
#   Repository: https://github.com/celebi-pkg/flight-analysis
#
# Repository: 2023AI (23)
#   Owner: joenghl
#   Description: 中山大学计算机学院2023春季人工智能课程
#   Repository: https://github.com/joenghl/2023AI
#
# Repository: D4-Autoskill (23)
#   Owner: juddisjudd
#   Description: Diablo IV Autoskill Script
#   Repository: https://github.com/juddisjudd/D4-Autoskill
#
# Repository: CBDQ-Python (23)
#   Owner: GuglioIsStupid
#   Description: Project to bring CBDQ bots back from the dead! (+ new functions)
#   Repository: https://github.com/GuglioIsStupid/CBDQ-Python
#
# Repository: Senpwai (23)
#   Owner: SenZmaKi
#   Description: Batch anime downloader app
#   Repository: https://github.com/SenZmaKi/Senpwai
#
# Repository: pyxui (23)
#   Owner: staliox
#   Description: An application to modify xui panel - v2ray v2rayng xui python
#   Repository: https://github.com/staliox/pyxui
#
# Repository: MUREN (23)
#   Owner: OreoChocolate
#   Description: The official code for Relational Context Learning for Human-Object Interaction Detection, CVPR2023.
#   Repository: https://github.com/OreoChocolate/MUREN
#
# Repository: rotorpy (23)
#   Owner: spencerfolk
#   Description: A multirotor simulator with aerodynamics for education and research.
#   Repository: https://github.com/spencerfolk/rotorpy
#
# Repository: Domain-Response (23)
#   Owner: Bert-JanP
#   Description: Domain Response is a tool that is designed to help you automate the investigation for a domain. This tool is specificly designed to automated phishing domain investigations. However it can be used for every domain to gather all domain information needed. This can help to classify if a domain is malicious.
#   Repository: https://github.com/Bert-JanP/Domain-Response
#
# Repository: ds4-tools (23)
#   Owner: carpikes
#   Description: Scripts I use to play and reverse-engineer the DualShock 4
#   Repository: https://github.com/carpikes/ds4-tools
#
# Repository: OpenHT-hw (23)
#   Owner: M17-Project
#   Description: Repository for the hardware parts of the OpenHT project
#   Repository: https://github.com/M17-Project/OpenHT-hw
#
# Repository: nikke-assistant (23)
#   Owner: KIvoy
#   Description: A python desktop app that helps with chores of Nikke: Godness of Victory
#   Repository: https://github.com/KIvoy/nikke-assistant
#
# Repository: paprika (23)
#   Owner: salesforce
#   Description: Code for CVPR 2023 paper "Procedure-Aware Pretraining for Instructional Video Understanding"
#   Repository: https://github.com/salesforce/paprika
#
# Repository: AR-Seg (23)
#   Owner: THU-LYJ-Lab
#   Description: [CVPR 2023] Efficient Semantic Segmentation by Altering Resolutions for Compressed Videos
#   Repository: https://github.com/THU-LYJ-Lab/AR-Seg
#
# Repository: ida-jm-xorstr-decrypt-plugin (23)
#   Owner: yubie-re
#   Description: Attempts to decrypt JM Xorstr in some x64 binaries
#   Repository: https://github.com/yubie-re/ida-jm-xorstr-decrypt-plugin
#
# Repository: Monero_Subscriptions_Wallet (23)
#   Owner: lukeprofits
#   Description: A Monero wallet that automatically pays subscriptions.
#   Repository: https://github.com/lukeprofits/Monero_Subscriptions_Wallet
#
# Repository: sonar_context (23)
#   Owner: sparolab
#   Description: Github repository of Sonar Context (ICRA 2023)
#   Repository: https://github.com/sparolab/sonar_context
#
# Repository: Intrepid (23)
#   Owner: microsoft
#   Description: INTeractive learning via REPresentatIon Discovery
#   Repository: https://github.com/microsoft/Intrepid
#
# Repository: RetMol (23)
#   Owner: NVlabs
#   Description: A new retrieval-based framework for controllable molecule generation.
#   Repository: https://github.com/NVlabs/RetMol
#
# Repository: max-vc (23)
#   Owner: MaxMax2016
#   Description: singing voice conversion without f0
#   Repository: https://github.com/MaxMax2016/max-vc
#
# Repository: flux-local (23)
#   Owner: allenporter
#   Description: flux-local is a set of tools and libraries for managing a local flux gitops repository focused on validation steps to help improve quality of commits, PRs, and general local testing.
#   Repository: https://github.com/allenporter/flux-local
#
# Repository: SpeechDewarping (23)
#   Owner: cnaigithub
#   Description: Official implementation of "Unsupervised Pre-training for Data-Efficient Text-to-Speech on Low Resource Languages", ICASSP 2023
#   Repository: https://github.com/cnaigithub/SpeechDewarping
#
# Repository: AMD-SP-Loader (23)
#   Owner: dayzerosec
#   Description: Binja loader for AMD-SP or PSP firmware binaries.
#   Repository: https://github.com/dayzerosec/AMD-SP-Loader
#
# Repository: FLW-Net (23)
#   Owner: hitzhangyu
#   Description: A Fast and Lightweight Network for Low-Light Image Enhancement
#   Repository: https://github.com/hitzhangyu/FLW-Net
#
# Repository: PyProto (23)
#   Owner: Ccccccccvvm
#   Description: protobuf pb-free file for group packet unpacking
#   Repository: https://github.com/Ccccccccvvm/PyProto
#
# Repository: bpc_calibration (23)
#   Owner: akhtarvision
#   Description: [CVPR 2023] Bridging Precision and Confidence: A Train-Time Loss for Calibrating Object Detection
#   Repository: https://github.com/akhtarvision/bpc_calibration
#
# Repository: MoleRec (23)
#   Owner: yangnianzu0515
#   Description: The official implementation of our paper "MoleRec: Combinatorial Drug Recommendation with Substructure-Aware Molecular Representation Learning" (TheWebConf 2023).
#   Repository: https://github.com/yangnianzu0515/MoleRec
#
# Repository: hazard-nuker-mirror (23)
#   Owner: KDot227
#   Description: The OFFICIAL mirror of hazard nuker (with updates and fixes)
#   Repository: https://github.com/KDot227/hazard-nuker-mirror
#
# Repository: drf-test-generator (23)
#   Owner: saadmk11
#   Description: A Django Package that generates basic unittest and pytest style tests for Django REST Framework ViewSets
#   Repository: https://github.com/saadmk11/drf-test-generator
#
# Repository: Polonium (23)
#   Owner: xKiian
#   Description: Check python code for malicious code or packages
#   Repository: https://github.com/xKiian/Polonium
#
# Repository: auxinash (23)
#   Owner: AvivSham
#   Description: Official implementation of Auxiliary learning as an Bargaining Game.
#   Repository: https://github.com/AvivSham/auxinash
#
# Repository: EgoNeRF (23)
#   Owner: changwoonchoi
#   Description: Official implementation of Balanced Spherical Grid for Egocentric View Synthesis (CVPR 2023)
#   Repository: https://github.com/changwoonchoi/EgoNeRF
#
# Repository: raven (23)
#   Owner: ahaliassos
#   Description: Official implementation of RAVEn (ICLR 2023)
#   Repository: https://github.com/ahaliassos/raven
#
# Repository: ComfyUI_TiledKSampler (23)
#   Owner: BlenderNeko
#   Description: Tiled samplers for ComfyUI
#   Repository: https://github.com/BlenderNeko/ComfyUI_TiledKSampler
#
# Repository: wemod-launcher (23)
#   Owner: DaniAsh551
#   Description: Tool made to launch the popular Game Trainer / Cheat tool WeMod along with your game (made for steam-runtime version in Linux).
#   Repository: https://github.com/DaniAsh551/wemod-launcher
#
# Repository: motion (23)
#   Owner: dm4ml
#   Description: MLOps framework for automatic continual learning & monitoring.
#   Repository: https://github.com/dm4ml/motion
#
# Repository: NasRec (23)
#   Owner: facebookresearch
#   Description: NASRec Weight Sharing Neural Architecture Search for Recommender Systems
#   Repository: https://github.com/facebookresearch/NasRec
#
# Repository: flet-django (23)
#   Owner: Marysia-Software-Limited
#   Description: Flet integration into a Django as complete frontend layer, call directly inside Django context.
#   Repository: https://github.com/Marysia-Software-Limited/flet-django
#
# Repository: IDvs.MoRec (23)
#   Owner: westlake-repl
#   Description: Recommender Systems, Modality-based Recommendation, Text Recommendation, Vision Recommendation
#   Repository: https://github.com/westlake-repl/IDvs.MoRec
#
# Repository: fastapi-todos (23)
#   Owner: eladgunders
#   Description: 🚀 async web server using FastAPI for to-do list apps
#   Repository: https://github.com/eladgunders/fastapi-todos
#
# Repository: WinClip (23)
#   Owner: caoyunkang
#   Description: [CVPR 2023] Unofficial re-implementation of "WinCLIP: Zero-/Few-Shot Anomaly Classification and Segmentation".
#   Repository: https://github.com/caoyunkang/WinClip
#
# Repository: rwkv-onnx (23)
#   Owner: RWKV
#   Description: A converter and basic tester for rwkv onnx
#   Repository: https://github.com/RWKV/rwkv-onnx
#
# Repository: data-morph (23)
#   Owner: stefmolin
#   Description: Morph an input dataset of 2D points into select shapes, while preserving the summary statistics to a given number of decimal points through simulated annealing.
#   Repository: https://github.com/stefmolin/data-morph
#
# Repository: retro-pixel-font (23)
#   Owner: TakWolf
#   Description: A set of open source old game style pixel fonts / 一组开源的有怀旧游戏感觉的像素字体
#   Repository: https://github.com/TakWolf/retro-pixel-font
#
# Repository: python-image-tools (23)
#   Owner: amirhamiri
#   Description: The python-image-tools is a python package that allows you to easily download an image from a given URL and manipulate it.
#   Repository: https://github.com/amirhamiri/python-image-tools
#
# Repository: BEVFormer_segmentation_detection (23)
#   Owner: Bin-ze
#   Description: Implemented BEVFormer support for BEV segmentation
#   Repository: https://github.com/Bin-ze/BEVFormer_segmentation_detection
#
# Repository: HomeTray (23)
#   Owner: vincentscode
#   Description: 💡 HomeTray is a small tool which lets you control your Home Assistant lights directly from your System Tray.
#   Repository: https://github.com/vincentscode/HomeTray
#
# Repository: tokenring (23)
#   Owner: glyph
#   Description: A backend for the `keyring` module which uses a hardware token to require user presence for any secret access, by encrypting your vault and passwords as Fernet tokens.
#   Repository: https://github.com/glyph/tokenring
#
# Repository: FastDepends (23)
#   Owner: Lancetnik
#   Description: FastDepends - FastAPI Dependency Injection system extracted from FastAPI and cleared of all HTTP logic. Async and sync modes are both supported.
#   Repository: https://github.com/Lancetnik/FastDepends
#
# Repository: music_caps_dl (23)
#   Owner: seungheondoh
#   Description: Unofficial download repository for MusicCaps
#   Repository: https://github.com/seungheondoh/music_caps_dl
#
# Repository: MT4-MT5-Forex-Signal-Copier-Telegram-Bot (22)
#   Owner: ogunjobiFX
#   Description: Telegram bot used for copying and entering signals from signal provider directly to MT4 and MT5 trading accounts with calculated lot sizes and profit/loss display
#   Repository: https://github.com/ogunjobiFX/MT4-MT5-Forex-Signal-Copier-Telegram-Bot
#
# Repository: ece250-testcases (22)
#   Owner: JZJisawesome
#   Description: ECE250 Testcases and Autograder
#   Repository: https://github.com/JZJisawesome/ece250-testcases
#
# Repository: Discord-phone-Verfier (22)
#   Owner: ApfelsaftDevs
#   Description: Discord phone Verfier 🔥 WORKING 2023🔥 VERY STRONG AND EFFICIENT TOOL TO MASS VERIFY DISCORD ACCOUNTS USING PHONE NUMBER!
#   Repository: https://github.com/ApfelsaftDevs/Discord-phone-Verfier
#
# Repository: okx (22)
#   Owner: pyted
#   Description: Python OKX API interface
#   Repository: https://github.com/pyted/okx
#
# Repository: LayerZeroStats (22)
#   Owner: Failton
#   Description: A simple script for downloading the LayerZero table from Dune and filtering by the specified wallets
#   Repository: https://github.com/Failton/LayerZeroStats
#
# Repository: maa-s-homework (22)
#   Owner: ntgmc
#   Description: MAA请看https://github.com/MaaAssistantArknights/MaaAssistantArknights 谢谢喵
#   Repository: https://github.com/ntgmc/maa-s-homework
#
# Repository: unSwear (22)
#   Owner: mhavelka77
#   Description: Curing toxicity by replacing curse words by harmless alternatives <3
#   Repository: https://github.com/mhavelka77/unSwear
#
# Repository: scenery_spider_web (22)
#   Owner: ChenZixinn
#   Description: Scrapy爬取去哪儿网，并使用Django框架+PyEcharts实现可视化大屏。
#   Repository: https://github.com/ChenZixinn/scenery_spider_web
#
# Repository: Discord-Fake-Nitro-Proof-Generator (22)
#   Owner: AstraaDev
#   Description: This Fake Proof generator allows you to generate an image (.png) simulating the donation of a nitro to a user. It is possible to choose by entering the ID a real user or to choose manually the name, the profile picture and the message of the user. The use of the script is done with the help of commands using Discord modals.
#   Repository: https://github.com/AstraaDev/Discord-Fake-Nitro-Proof-Generator
#
# Repository: rlt2t (22)
#   Owner: nilboy
#   Description: Text to text with reinforcement learning
#   Repository: https://github.com/nilboy/rlt2t
#
# Repository: Spark-Streaming-Kafka2Elasticsearch (22)
#   Owner: addyclement
#   Description: Spark Streaming Pipeline - Kafka to Elasticsearch
#   Repository: https://github.com/addyclement/Spark-Streaming-Kafka2Elasticsearch
#
# Repository: Stresser7 (22)
#   Owner: Pari-Malam
#   Description: Perform With DDoS Attack Tool-KID.
#   Repository: https://github.com/Pari-Malam/Stresser7
